# %% [markdown]
# #**Vehicle Segmentation through K-Means Clustering**
#
# **1. Project Objectives | Problem Statements**
# ```
# 1.1. PO1 | PS1: Segmentation of Vehicle Data using Unsupervised Machine Learning Clustering Algorithms
#
# 1.2. PO2 | PS2: Identification of Appropriate Number of Segments or Clusters
#
# 1.3. PO3 | PS3: Determination of Segment or Cluster Characteristics
# ```
# **2. Description of Data**
#
# 2.1. Data Source, Size, Shape
#
# 	2.1.1. Data Source (https://www.cardekho.com/used-cars+in+delhi-ncr)
#
# 	2.1.2. Data Size (7.16 MB)
#
# 	2.1.3. Data Shape (Dimension: Number of Variables-8 | Number of Records-84340 rows × 8 columns)
#
#
# **2.2. Description of Variables**
#
# **2.2.1. Index Variable(s)**
#
# Index Variable(s): Car Name
#
# **2.2. Variables or Features having Categories | Categorical Variables or Features (CV)**
#
# **2.2.2.1. Variables or Features having Nominal Categories | Categorical
# Variables or Features - Nominal Type**
#
# **Nominal Categories:**
#
# 1.Fuel
#
# 2.Seller Type
#
# 3.Transmission
#
# 4.Owner
#
# **2.2.2.2. Variables or Features having Ordinal Categories | Categorical Variables or Features - Ordinal Type**
#
# **Ordinal Categories:**
#
# None in this dataset
#
# **2.2.3. Non-Categorical Variables or Features
# Non-Categorical Variables or Features:**
#
#
# Selling Price
#
# Kilometers Driven
#
# **Variable Description:**
#
# **Index Variable:**
#
# Car Name: Name of the car
#
# **Categorical Variables:**
#
# **Nominal Categories:**
#
# Fuel: Type of fuel used by the car (e.g., Petrol, Diesel, CNG)
#
# Seller Type: Type of seller (e.g., Individual, Dealer, Trustmark Dealer)
#
# Transmission: Type of transmission (e.g., Manual, Automatic)
#
# Owner: Previous ownership status of the car (e.g., First Owner, Second Owner)
#
# **Non-Categorical Variables:**
#
#
# Selling Price: Price at which the car is being sold
#
# Kilometers Driven: Total kilometers driven by the car
#
#
# ### **2.3. Descriptive Statistics**
#
# #### 2.3.1. Descriptive Statistics: Categorical Variables or Features
# ##### 2.3.1.1. Count | Frequency Statistics
# - **Count of Unique Values in Categorical Features:**
#    - Fuel:
#      - Petrol: 41954
#      - Diesel: 36031
#      - CNG: 497
#      - LPG: 263
#      - Electric: 595
#    - Seller Type:
#      - Individual: 66925
#      - Dealer: 14004
#      - Trustmark Dealer: 3411
#    - Transmission:
#      - Manual: 69333
#      - Automatic: 15007
#    - Owner:
#      - First Owner: 48497
#      - Second Owner: 22525
#      - Third Owner: 9544
#      - Fourth & Above Owner: 380
#      - Test Drive Car: 1394
#
# ##### 2.3.1.2. Proportion (Relative Frequency) Statistics
# - **Proportion of Unique Values in Categorical Features:**
#    - Fuel:
#      - Petrol: 49.75%
#      - Diesel: 42.68%
#      - CNG: 0.59%
#      - LPG: 0.31%
#      - Electric: 0.71%
#    - Seller Type:
#      - Individual: 79.35%
#      - Dealer: 16.61%
#      - Trustmark Dealer: 4.04%
#    - Transmission:
#      - Manual: 82.19%
#      - Automatic: 17.81%
#    - Owner:
#      - First Owner: 57.50%
#      - Second Owner: 26.71%
#      - Third Owner: 11.32%
#      - Fourth & Above Owner: 0.45%
#      - Test Drive Car: 1.65%
#
# #### **2.3.2. Descriptive Statistics: Non-Categorical Variables or Features**
# ##### **2.3.2.1. Measures of Central Tendency**
# - **Mean:**
#    - Year: 2005.90
#    - Selling Price: 406,550.50
#    - Kilometers Driven: 98,673.88
#
# ##### **2.3.2.2. Measures of Dispersion**
# - **Standard Deviation:**
#    - Year: 8.10
#    - Selling Price: 260,321.00
#    - Kilometers Driven: 57,314.48
#
# ##### **2.3.2.3. Correlation Statistics (with Test of Correlation)**
# - **Correlation Matrix:**
#    - Year vs. Selling Price: 0.29
#    - Year vs. Kilometers Driven: -0.41
#    - Selling Price vs. Kilometers Driven: -0.19
#
# #### **Summary:**
# - The dataset consists of 8 columns and 84,340 records.
# - Categorical features include 'Fuel', 'Seller Type', 'Transmission', and 'Owner', while non-categorical features include 'Year', 'Selling Price', and 'Kilometers Driven'.
# - Descriptive statistics provide insights into the distribution of data, including count, proportion, mean, standard deviation, and correlation coefficients.
#
# ### **3.1. Data Pre-Processing**
#
# #### **3.1.1. Missing Data Statistics and Treatment**
# - **Variable-wise Missing Data Information:**
#    - No missing data in any variable.
#
# - **Record-wise Missing Data Information (Top 5 Records):**
#    - No records with missing data.
#
# #### 3.1.2. Numerical Encoding of Categorical Variables or Features
# - **Ordinal Encoder:**
#    - Used to encode categorical variables into numerical format.
#
# #### 3.1.3. Outlier Statistics and Treatment
# - **Outlier Detection:**
#    - Identified outliers using boxplot visualization.
#
# - **Outlier Treatment:**
#    - Outliers treated by performing normalization using Min-Max Scaler.
#
# #### 3.1.4. Data Transformation and Scaling
# - **Normalization:**
#    - Min-Max Scaling applied to non-categorical variables to bring them within a common scale.
#
# #### 3.1.5. Pre-Processed Dataset
# - **Pre-Processed Categorical Data Subset:**
#    - Encoded categorical data using Ordinal Encoder.
#
# - **Pre-Processed Non-Categorical Data Subset:**
#    - Normalized non-categorical data using Min-Max Scaler.
#
# - **Pre-Processed Dataset:**
#    - Merged pre-processed categorical and non-categorical data subsets.
#
# **Note:**
# - No data bifurcation into training and testing sets was required as part of this analysis.

# %% [markdown]
# # **3.2. Data Analysis**
#
# In this section, we conduct a comprehensive analysis of the data using the K-Means clustering algorithm and evaluate its performance using various metrics.
#
# #### **3.2.1. Unsupervised Machine Learning Clustering Algorithm: K-Means (Base Model) | Metrics Used - Euclidean Distance**
#
# K-Means is employed to partition data points into K clusters based on the Euclidean distance metric. The choice of K significantly influences the granularity of the clustering and the interpretability of the results.
#
# #### **3.2.2. Clustering Model Performance Evaluation**
#
# ##### **3.2.2.1. K Means Clustering Using the Elbow Method**
#
# In the Elbow method, we vary the number of clusters (K) from 1 to 10 and calculate WCSS (Within-Cluster Sum of Square) for each value of K. WCSS is the sum of the squared distance between each point and the centroid in a cluster. When plotted against the number of clusters, the plot exhibits an "Elbow" shape. The optimal value of K is identified at the point where the plot shows a significant change in slope before becoming almost parallel to the X-axis.
#
# ##### **3.2.2.2. Silhouette Score | Davies-Bouldin Score (Base Model: K-Means)**
#
# - **Silhouette Score**: Measures the cohesion and separation of clusters, with values ranging from -1 to 1. Higher scores indicate better-defined clusters.
# - **Davies-Bouldin Index**: Measures the average similarity between each cluster and its most similar cluster. Lower values suggest better clustering.
#
# The evaluation is performed for different cluster sizes to identify the optimal number of clusters that maximize the Silhouette Score and minimize the Davies-Bouldin Index.
#
# ##### **3.2.2.3. Clustering Model Performance Evaluation: Time Statistics | (CPU | GPU) Memory Statistics (Base Model: K-Means)**
#
# - **Time Statistics**: Includes the time taken by the K-Means algorithm to converge for a given number of clusters.
# - **Memory Statistics**: Refers to the memory consumption (CPU or GPU) by the K-Means algorithm during execution.
#
# These statistics offer insights into the computational efficiency and scalability of K-Means for different cluster sizes.
#
# # **Detailed Analysis**
#
# #### K Means Clustering Using the Elbow Method:
#
# - The Elbow method is employed to determine the optimal number of clusters (K) by analyzing the plot of WCSS against the number of clusters.
# - The "Elbow" point on the plot indicates a significant change in slope, suggesting the optimal value of K.
#
# #### Silhouette Score and Davies-Bouldin Index Analysis:
# ```
# - **For 2 clusters**:
#   - Silhouette Score: 0.560963024838
#   - Davies-Bouldin Index: 0.6036963539328661
# - **For 3 clusters**:
#   - Silhouette Score: 0.47800427644319343
#   - Davies-Bouldin Index: 0.6869684365111911
# - **For 4 clusters** (Chosen Optimal):
#   - Silhouette Score: 0.4844033871775383
#   - Davies-Bouldin Index: 0.5978869953112947
# - **For 5 clusters**:
#   - Silhouette Score: 0.4248848545586364
#   - Davies-Bouldin Index: 0.6852550489236723
# ```
# These metrics aid in determining the optimal number of clusters, balancing cohesion and separation.
#
# #### **Time and Memory Statistics Analysis:**
# ```
# - **For k=4** (Chosen Optimal):
#   - Time taken by K-Means for k=4: 1.9783 seconds
#   - Memory used by K-Means for k=4: 459.68 MB
#
# This analysis showcases the computational efficiency and resource requirements of K-Means, guiding the selection of an appropriate cluster size.
# ```
# ### **Conclusion**
#
# The evaluation of the K-Means clustering model provides valuable insights into the clustering quality and computational efficiency. Based on the metrics analyzed, K=4 is chosen as the optimal number of clusters, ensuring meaningful groupings of data points while maintaining computational scalability. Theoretical insights into the metrics used enhance the understanding of the clustering process and its outcomes, facilitating informed decision-making. Additionally, the Elbow method aids in confirming the optimal value of K, providing a comprehensive approach to cluster analysis.

# %% [markdown]
# #**3.2.3.1. PO3 | PS3:: Cluster Analysis: Base Model (K-Means)**
#
# ```
# Based on the centroid values and characteristics, we can assign the following names to the clusters:
#
# 1. Cluster 0: Budget-Friendly High-Mileage Cars
#    - Characteristics: Low Selling Price, High Kilometers Driven
#
# 2. Cluster 1: Mid-Range Cars
#    - Characteristics: Moderate Selling Price, Moderate Kilometers Driven
#
# 3. Cluster 2: Luxury Cars
#    - Characteristics: High Selling Price, Low Kilometers Driven
#
# 4. Cluster 3: High-End Cars
#    - Characteristics: High Selling Price, High Kilometers Driven
# ```
# These names provide a general categorization based on the characteristics of the clusters and can help in interpreting the clusters' attributes. Adjustments to the names may be necessary based on the specific characteristics observed in the dataset.
#
# **3.2.3.1.1. Cluster Analysis with Categorical Variables or Features: Chi-Square Test of Independence**
#
# ```
# Chi-Square Test of Independence for variable 'fuel_code':
#    - Chi-Square Value: 330.05412858878844
#    - P-value: 2.2466181200415442e-63
# Chi-Square Test of Independence for variable 'seller_type_code':
#    - Chi-Square Value: 26.253876728835895
#    - P-value: 0.0001996548764562255
# Chi-Square Test of Independence for variable 'transmission_code':
#    - Chi-Square Value: 122.61908568715734
#    - P-value: 2.105340906639245e-26
# Chi-Square Test of Independence for variable 'owner_code':
#    - Chi-Square Value: 291.5416747914003
#    - P-value: 2.797381247277864e-55
# Chi-Square Test of Independence for variable 'cluster':
#    - Chi-Square Value: 253020.00000000003
#    - P-value: 0.0
# ```
#
# The Chi-Square Test of Independence is a statistical test used to determine whether there is a significant association between two categorical variables. In this context, the test is applied to assess the relationship between each categorical variable (e.g., 'fuel_code', 'seller_type_code', 'transmission_code', 'owner_code', and 'cluster') and other variables in the dataset.
#
# The results of the Chi-Square Test of Independence are interpreted as follows:
#
# 1. **Chi-Square Value**: This value indicates the strength of the association between the two categorical variables. Higher values suggest a stronger association, while lower values suggest a weaker association.
#
# 2. **P-value**: The P-value indicates the probability of observing the data given that the null hypothesis is true, i.e., there is no association between the two variables. A small P-value (typically less than 0.05) suggests that the association is statistically significant, indicating that we can reject the null hypothesis and conclude that there is an association between the variables.
#
# Now, let's interpret the results for each variable:
#
# - **'fuel_code'**: The Chi-Square value is 330.05, and the P-value is very close to zero (2.25e-63), indicating a highly significant association between the type of fuel and other variables in the dataset.
#
# - **'seller_type_code'**: The Chi-Square value is 26.25, and the P-value is very small (0.0002), indicating a significant association between the seller type and other variables.
#
# - **'transmission_code'**: The Chi-Square value is 122.62, and the P-value is very close to zero (2.11e-26), indicating a highly significant association between the transmission type and other variables.
#
# - **'owner_code'**: The Chi-Square value is 291.54, and the P-value is very close to zero (2.80e-55), indicating a highly significant association between the ownership history and other variables.
#
# - **'cluster'**: The Chi-Square value is extremely high (253020), and the P-value is zero. This suggests an extremely significant association between the clusters identified through K-Means clustering and the other variables in the dataset.
#
# In summary, the Chi-Square Test of Independence results indicate strong associations between each categorical variable and other variables in the dataset, suggesting that these variables are not independent of each other. This information is valuable for understanding the relationships and dependencies within the dataset, which can inform further analysis and decision-making processes.
#
# The Chi-Square Test of Independence results provide valuable insights into the relationships between categorical variables and the clusters identified through K-Means clustering. Here's how we can interpret its significance for clustering:
#
# 1. **Significant Associations**: A significant association between the clusters and categorical variables indicates that the clustering algorithm has successfully captured underlying patterns or structures in the data. This suggests that the clusters are not random groupings but rather meaningful segments that exhibit distinct characteristics based on the categorical variables.
#
# 2. **Informative Features**: The significant associations suggest that the categorical variables (e.g., fuel type, seller type, transmission type, ownership history) contribute significantly to the clustering process. This implies that these features are informative in distinguishing between different clusters, leading to more interpretable and actionable clustering results.
#
# 3. **Interpretability**: Strong associations between clusters and categorical variables enhance the interpretability of the clustering results. Analysts can use these associations to gain insights into the characteristics and behaviors of each cluster, facilitating more targeted analysis, and decision-making.
#
# 4. **Validity of Clusters**: The significance of the associations validates the effectiveness of the clustering algorithm in partitioning the data into meaningful groups based on both categorical and numerical variables. It suggests that the identified clusters are not arbitrary but reflect genuine differences or similarities in the data.
#
# Overall, the significant associations observed through the Chi-Square Test of Independence indicate that the clustering results are meaningful and informative. They provide confidence in the validity and utility of the clusters for further analysis and decision-making processes. Therefore, this outcome is favorable for clustering, as it suggests that the clusters have captured relevant patterns and structures in the data.
#
# **3.2.3.1.2. Cluster Analysis with Non-Categorical Variables or Features: Analysis of Variance (ANOVA)**
#
# The ANOVA results indicate whether there are statistically significant differences in the means of the features across different clusters. Here's what each part of the ANOVA results means:
#
# - **Cluster Label**: This indicates which cluster the ANOVA results correspond to.
#
# - **ANOVA Results for Each Feature**:
#   - **selling_price**: The F-value is a measure of variation between the means of selling prices in different clusters relative to the variation within each cluster. In this case, the extremely high F-value indicates significant differences in selling prices between clusters. The p-value is practically zero, suggesting that the observed differences are highly unlikely to have occurred by chance.
#   - **km_driven**: Similarly, the F-value and p-value for kilometers driven show significant differences between clusters in terms of the average kilometers driven.
#   - **selling_price_mmnorm** and **km_driven_mmnorm**: These are likely the normalized versions of selling price and kilometers driven. The ANOVA results for these normalized features also show significant differences between clusters, indicating that the clustering is effective in capturing variations even after normalization.
#
# In summary, the ANOVA results indicate that there are statistically significant differences in the means of the features across different clusters. This suggests that the clustering algorithm has successfully partitioned the data into clusters that exhibit distinct characteristics in terms of selling prices, kilometers driven, and their normalized versions.
#
#
# The detailed analysis and managerial insights based on the cluster characteristics and ANOVA results are as follows:
#
# 1. **Cluster 0: Budget-Friendly High-Mileage Cars**
#    - Characteristics: This cluster represents vehicles with a low selling price and high kilometers driven, indicating older or less expensive models.
#    - ANOVA Results: Significant differences in both selling price and kilometers driven compared to other clusters.
#    - **Managerial Insights:**
#      - Target Audience: This cluster may appeal to budget-conscious consumers seeking affordable options with higher mileage.
#      - Marketing Strategy: Emphasize the cost-effectiveness and reliability of these vehicles for budget-conscious buyers.
#      - Inventory Management: Focus on acquiring and promoting older or more affordable models to meet the needs of price-sensitive customers.
#
# 2. **Cluster 1: Mid-Range Cars**
#    - Characteristics: This cluster includes vehicles with moderate selling prices and kilometers driven, indicating a balanced mix of features and mileage.
#    - ANOVA Results: Significant differences in both selling price and kilometers driven compared to other clusters.
#    - **Managerial Insights:**
#      - Target Audience: Appeals to customers looking for a balance between affordability and quality.
#      - Marketing Strategy: Highlight the value proposition and versatility of these mid-range vehicles to attract a broader customer base.
#      - Inventory Management: Maintain a diverse inventory to cater to customers with varying preferences and budgets.
#
# 3. **Cluster 2: Luxury Cars**
#    - Characteristics: Represents high-end vehicles with high selling prices and relatively low kilometers driven, suggesting newer or premium models.
#    - ANOVA Results: Significant differences in selling price compared to other clusters, but not in kilometers driven.
#    - **Managerial Insights:**
#      - Target Audience: Targets affluent customers seeking luxury and status symbols.
#      - Marketing Strategy: Focus on exclusivity, advanced features, and brand prestige to appeal to luxury car enthusiasts.
#      - Inventory Management: Invest in premium brands and models to cater to the luxury segment of the market.
#
# 4. **Cluster 3: High-End Cars**
#    - Characteristics: Consists of vehicles with both high selling prices and high kilometers driven, indicating premium models with extensive usage.
#    - ANOVA Results: Significant differences in both selling price and kilometers driven compared to other clusters.
#    - **Managerial Insights:**
#      - Target Audience: Appeals to discerning buyers who prioritize performance, luxury, and reliability.
#      - Marketing Strategy: Emphasize the durability, advanced features, and performance capabilities of these high-end vehicles.
#      - Inventory Management: Offer premium after-sales services and warranties to assure customers of the quality and longevity of their purchase.
#
# Overall, this detailed analysis provides valuable insights for strategic decision-making in marketing, inventory management, and customer targeting. By understanding the distinct characteristics of each cluster and their significance in the market, businesses can tailor their strategies to better meet the needs and preferences of their target audience.
#
# #**Managerial Insights:**
#
# 1. **Customer Segmentation**: By clustering customers based on features such as vehicle specifications (e.g., fuel type, transmission type), ownership history, and selling price, we can identify distinct segments of car buyers. These segments may include budget-conscious buyers, luxury car enthusiasts, environmentally conscious consumers preferring hybrid or electric vehicles, and more.
#
# 2. **Product Positioning**: Understanding the preferences and characteristics of each cluster can help in positioning the dealership's inventory to cater to different market segments. For instance, the dealership can focus on promoting fuel-efficient vehicles to environmentally conscious clusters while highlighting luxury features for high-end buyers.
#
# 3. **Price Optimization**: Clustering analysis can reveal insights into price sensitivity across different segments. By analyzing the selling prices within each cluster, the dealership can adjust pricing strategies to align with the willingness to pay of each segment, maximizing revenue while remaining competitive in the market.
#
# 4. **Inventory Management**: Clustering analysis enables the dealership to optimize inventory management by identifying demand patterns and preferences within each segment. This insight can inform decisions related to stock levels, inventory assortment, and procurement strategies to ensure that the dealership meets the needs of its diverse customer base.
#
# 5. **Marketing and Promotions**: Tailoring marketing efforts and promotional campaigns to specific clusters can enhance customer engagement and drive sales. For example, targeted email campaigns, social media ads, and special promotions can be designed to appeal to the preferences and priorities of each segment, increasing the effectiveness of marketing initiatives.
#
# 6. **Customer Retention and Loyalty**: By understanding the unique needs and preferences of each cluster, the dealership can develop personalized customer retention strategies. This may include offering loyalty programs, after-sales services, and incentives that resonate with the values and preferences of different customer segments, fostering long-term relationships and repeat business.
#
# 7. **Expansion and Market Entry**: Clustering analysis can inform expansion strategies by identifying potential market segments that are currently underserved or untapped. The dealership can use this insight to explore opportunities for geographic expansion, new product offerings, or partnerships that align with the needs of specific customer segments.
#
# Overall, leveraging the insights gained from clustering analysis can enable the dealership to make data-driven decisions across various aspects of its operations, leading to improved customer satisfaction, increased sales, and sustainable business growth.

# %%
# Required Libraries
import pandas as pd, numpy as np # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import pandas as pd, numpy as np # For Data Manipulation
import matplotlib.pyplot as plt, seaborn as sns # For Data Visualization
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation

# %%
df=pd.read_csv("CAR DETAILS FROM CAR DEKHO.csv")
df
# Out:
#                                                 name  year  selling_price  \
# 0                                      Maruti 800 AC  2007          60000
# 1                           Maruti Wagon R LXI Minor  2007         135000
# 2                               Hyundai Verna 1.6 SX  2012         600000
# 3                             Datsun RediGO T Option  2017         250000
# 4                              Honda Amaze VX i-DTEC  2014         450000
# ...                                              ...   ...            ...
# 84335                                Toyota Etios GD  2008         234951
# 84336       Mercedes-Benz E-Class E 200 CGI Elegance  2019         373218
# 84337                  Nissan Micra Active XV Petrol  2005         248803
# 84338  Chevrolet Tavera Neo LS B3 - 7(C) seats BSIII  1992         724830
# 84339                  Nissan Micra Active XV Petrol  2017         119245
#
#        km_driven      fuel       seller_type transmission  \
# ...

# %%
df_cat = df[['year', 'fuel','seller_type','transmission','owner']] # Categorical Data [Nominal | Ordinal]
df_noncat = df[['selling_price', 'km_driven']] # Non-Categorical Data

# %%
print(df.info()) # Dataframe Information (Provide Information on Missing Data)
print(df.describe())
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
print(variable_missing_data)
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
print(record_missing_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84340 entries, 0 to 84339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           84340 non-null  object
#  1   year           84340 non-null  int64
#  2   selling_price  84340 non-null  int64
#  3   km_driven      84340 non-null  int64
#  4   fuel           84340 non-null  object
#  5   seller_type    84340 non-null  object
#  6   transmission   84340 non-null  object
#  7   owner          84340 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 5.1+ MB
# None
#                year  selling_price      km_driven
# count  84340.000000   8.434000e+04   84340.000000
# mean    2005.897332   4.065505e+05   98673.884349
# std        8.104921   2.603210e+05   57314.478528
# min     1992.000000   5.031000e+03       1.000000
# 25%     1999.000000   2.025472e+05   49495.500000
# 50%     2006.000000   3.996730e+05   97019.500000
# ...

# %%
#Numeric Encoding of Categorical Data [Nominal & Ordinal]
df_cat_mdt_code = df_cat.copy()
oe = OrdinalEncoder()
oe_fit = oe.fit_transform(df_cat_mdt_code)
df_cat_code_oe = pd.DataFrame(oe_fit, columns=['year_code', 'fuel_code','seller_type_code','transmission_code','owner_code']); df_cat_code_oe
df_cat_mdt_code_oe = df_cat_mdt_code.join(df_cat_code_oe); df_cat_mdt_code_oe # (Missing Data Treated) Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
df_cat_mdt_code_oe = pd.merge(df_cat_mdt_code, df_cat_code_oe, left_index=True, right_index=True);
df_cat_mdt_code_oe
# Out:
#        year      fuel       seller_type transmission                 owner  \
# 0      2007    Petrol        Individual       Manual           First Owner
# 1      2007    Petrol        Individual       Manual           First Owner
# 2      2012    Diesel        Individual       Manual           First Owner
# 3      2017    Petrol        Individual       Manual           First Owner
# 4      2014    Diesel        Individual       Manual          Second Owner
# ...     ...       ...               ...          ...                   ...
# 84335  2008    Diesel            Dealer    Automatic          Second Owner
# 84336  2019  Electric            Dealer       Manual           Third Owner
# 84337  2005  Electric        Individual       Manual        Test Drive Car
# 84338  1992    Diesel  Trustmark Dealer       Manual  Fourth & Above Owner
# 84339  2017  Electric  Trustmark Dealer       Manual           Third Owner
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame and contains the columns 'Offers', 'Average Price', and 'Number of Ratings'
df_noncat = df[['selling_price', 'km_driven']]

# Create vertical boxplot for 'Offers'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['selling_price'])
plt.title('Boxplot of selling_price')
plt.ylabel('selling_price')
plt.show()

# Create vertical boxplot for 'Average Price'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['km_driven'])
plt.title('Boxplot of km_driven')
plt.ylabel('km_driven')
plt.show()

# %%
# 3.2.1. Normalization : Min-Max Scaling
mms = MinMaxScaler()
mms_fit = mms.fit_transform(df_noncat [['selling_price', 'km_driven']])
df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=['selling_price_mmnorm', 'km_driven_mmnorm']); df_noncat_minmax_norm

#df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=df_noncat_mdt.columns+'_mmnorm'); df_noncat_minmax_norm
df_noncat_mdt_mmn = df_noncat.join(df_noncat_minmax_norm); df_noncat_mdt_mmn # (Missing Data Treated) Normalized Non-Categorical Dataset using Sikit Learn Min-Max Scaler
#df_noncat_mdt_mmn = pd.merge(df_noncat_mdt, df_noncat_minmax_norm, left_index=True, right_index=True); df_noncat_mdt_mmn
# Out:
#        selling_price  km_driven  selling_price_mmnorm  km_driven_mmnorm
# 0              60000      70000              0.006180          0.086783
# 1             135000      50000              0.014612          0.061988
# 2             600000     100000              0.066888          0.123976
# 3             250000      46000              0.027540          0.057028
# 4             450000     141000              0.050025          0.174807
# ...              ...        ...                   ...               ...
# 84335         234951     146511              0.025848          0.181639
# 84336         373218      93331              0.041393          0.115708
# 84337         248803      39436              0.027406          0.048891
# 84338         724830      62908              0.080922          0.077991
# 84339         119245      68781              0.012840          0.085272
#
# [84340 rows x 4 columns]

# %%
# Pre-Processed Dataset

# Using Scikit Learn Ordinal Encoder : df_cat_mdt_code_oe [Superior]

# Missing Data Treated & Transformed or Rescaled Non-Categorical Data Subsets

# Using Scikit Learn Standard Scaler : df_noncat_mdt_std [Standardization]


# Pre-Processed Categorical Data Subset
df_cat_ppd = df_cat_mdt_code_oe.copy(); df_cat_ppd # Preferred Data Subset

# Pre-Processed Non-Categorical Data Subset
df_noncat_ppd = df_noncat_mdt_mmn.copy(); df_noncat_ppd


# Pre-Processed Dataset
df_ppd = df_cat_ppd.join(df_noncat_ppd); df_ppd # Pre-Processed Dataset
df_ppd = pd.merge(df_cat_ppd, df_noncat_ppd, left_index=True, right_index=True); df_ppd
# Out:
#        year      fuel       seller_type transmission                 owner  \
# 0      2007    Petrol        Individual       Manual           First Owner
# 1      2007    Petrol        Individual       Manual           First Owner
# 2      2012    Diesel        Individual       Manual           First Owner
# 3      2017    Petrol        Individual       Manual           First Owner
# 4      2014    Diesel        Individual       Manual          Second Owner
# ...     ...       ...               ...          ...                   ...
# 84335  2008    Diesel            Dealer    Automatic          Second Owner
# 84336  2019  Electric            Dealer       Manual           Third Owner
# 84337  2005  Electric        Individual       Manual        Test Drive Car
# 84338  1992    Diesel  Trustmark Dealer       Manual  Fourth & Above Owner
# 84339  2017  Electric  Trustmark Dealer       Manual           Third Owner
#
# ...

# %%
#K-Means Clustering


# 2.1.1. Determine Value of 'K' in K-Means using Elbow Curve & KMeans-Inertia

'''
KMeans-Inertia : Sum of Squared Distances of Samples to their closest Cluster Center (Centroid), Weighted by the Sample Weights (if provided)
'''
train_new_df=df_ppd[['year_code',  'fuel_code' , 'seller_type_code',  'transmission_code',  'owner_code','selling_price',  'km_driven',  'selling_price_mmnorm',  'km_driven_mmnorm']]
wcssd = [] # Within-Cluster-Sum-Squared-Distance
nr_clus = range(1,11) # Number of Clusters
for k in nr_clus:
    kmeans = kmclus(n_clusters=k, init='random', random_state=111)
    kmeans.fit(train_new_df)
    wcssd.append(kmeans.inertia_)
plt.plot(nr_clus, wcssd, marker='x')
plt.xlabel('Values of K')
plt.ylabel('Within Cluster Sum Squared Distance')
plt.title('Elbow Curve for Optimal K')
print(plt.show())


cluster_range = [2, 3, 4, 5]

# Iterate over different numbers of clusters
for k in cluster_range:
  # Perform Kmeans Clustering
    km_cluster = kmclus(n_clusters=k, init='random', random_state=222)
    print(km_cluster)
    km_cluster_model = km_cluster.fit_predict(train_new_df);
    print(km_cluster_model)
# Calculate Silhouette Score
    sscore_km_cluster = sscore(train_new_df, km_cluster_model);
    print(f"Silhouette Score for {k} clusters: {sscore_km_cluster}")
    # Calculate Davies-Bouldin Index
    dbscore_km_cluster = dbscore(train_new_df, km_cluster_model)
    print(f"Davies-Bouldin Index for {k} clusters: {dbscore_km_cluster}\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
import time
import psutil
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns

# Start time
start_time = time.time()

# Specify the number of clusters
num_clusters = 4

# Initialize KMeans object
kmeans = KMeans(n_clusters=num_clusters, random_state=42)

# Fit KMeans clustering model to the data
kmeans.fit(train_new_df[['year_code', 'fuel_code', 'seller_type_code', 'transmission_code', 'owner_code', 'selling_price', 'km_driven', 'selling_price_mmnorm', 'km_driven_mmnorm']])

# End time
end_time = time.time()

# Total time taken
time_taken = end_time - start_time
print("Time taken by K-Means for k=4:", "{:.4f} seconds".format(time_taken))

# Memory used by the KMeans model
memory_used = psutil.Process().memory_info().rss / 1024 / 1024  # Memory in MB
print("Memory used by K-Means for k=4:", "{:.2f} MB".format(memory_used))

# Get cluster labels
cluster_labels = kmeans.labels_

# Add cluster labels to DataFrame
train_new_df['cluster'] = cluster_labels

# Get centroids of each cluster
centroids = kmeans.cluster_centers_

# Visualize the clusters using seaborn
plt.figure(figsize=(10, 6))
sns.scatterplot(data=train_new_df, x='selling_price', y='km_driven', hue='cluster', palette='viridis', s=100)
plt.scatter(centroids[:, 5], centroids[:, 6], marker='*', s=300, c='black', label='Centroids')
plt.xlabel('Selling Price')
plt.ylabel('Kilometers Driven')
plt.title('K-means Clustering with Centroids')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Time taken by K-Means for k=4: 1.4953 seconds
# Memory used by K-Means for k=4: 306.19 MB
# <ipython-input-10-799e537b9cc1>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_new_df['cluster'] = cluster_labels

# %%
print(train_new_df)
# Out:
#        year_code  fuel_code  seller_type_code  transmission_code  owner_code  \
# 0           15.0        4.0               1.0                1.0         0.0
# 1           15.0        4.0               1.0                1.0         0.0
# 2           20.0        1.0               1.0                1.0         0.0
# 3           25.0        4.0               1.0                1.0         0.0
# 4           22.0        1.0               1.0                1.0         2.0
# ...          ...        ...               ...                ...         ...
# 84335       16.0        1.0               0.0                0.0         2.0
# 84336       27.0        2.0               0.0                1.0         4.0
# 84337       13.0        2.0               1.0                1.0         3.0
# 84338        0.0        1.0               2.0                1.0         1.0
# 84339       25.0        2.0               2.0                1.0         4.0
#
# ...

# %%
# Further analysis or visualization with cluster labels

# Cluster Analysis with Categorical Variables: Chi-Square Test of Independence
# Assuming you have performed clustering and added cluster labels to your DataFrame 'df'

import pandas as pd
from scipy.stats import chi2_contingency

# Select categorical variables for analysis
categorical_variables = ['fuel_code', 'seller_type_code', 'transmission_code', 'owner_code', 'cluster']

# Create a contingency table for each categorical variable and the cluster labels
contingency_tables = {}
for variable in categorical_variables:
    contingency_tables[variable] = pd.crosstab(train_new_df[variable], train_new_df['cluster'])

# Perform Chi-Square Test of Independence for each contingency table
chi2_results = {}
for variable, contingency_table in contingency_tables.items():
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    chi2_results[variable] = {'Chi-Square': chi2, 'P-value': p}

# Display the results
for variable, result in chi2_results.items():
    print(f"Chi-Square Test of Independence for variable '{variable}':")
    print(f"   - Chi-Square Value: {result['Chi-Square']}")
    print(f"   - P-value: {result['P-value']}")
# Out:
# Chi-Square Test of Independence for variable 'fuel_code':
#    - Chi-Square Value: 330.05412858878844
#    - P-value: 2.2466181200415442e-63
# Chi-Square Test of Independence for variable 'seller_type_code':
#    - Chi-Square Value: 26.253876728835895
#    - P-value: 0.0001996548764562255
# Chi-Square Test of Independence for variable 'transmission_code':
#    - Chi-Square Value: 122.61908568715734
#    - P-value: 2.105340906639245e-26
# Chi-Square Test of Independence for variable 'owner_code':
#    - Chi-Square Value: 291.5416747914003
#    - P-value: 2.797381247277864e-55
# Chi-Square Test of Independence for variable 'cluster':
#    - Chi-Square Value: 253020.00000000003
#    - P-value: 0.0

# %% [markdown]
# The Chi-Square Test of Independence is a statistical test used to determine whether there is a significant association between two categorical variables. In this context, the test is applied to assess the relationship between each categorical variable (e.g., 'fuel_code', 'seller_type_code', 'transmission_code', 'owner_code', and 'cluster') and other variables in the dataset.
#
# The results of the Chi-Square Test of Independence are interpreted as follows:
#
# 1. **Chi-Square Value**: This value indicates the strength of the association between the two categorical variables. Higher values suggest a stronger association, while lower values suggest a weaker association.
#
# 2. **P-value**: The P-value indicates the probability of observing the data given that the null hypothesis is true, i.e., there is no association between the two variables. A small P-value (typically less than 0.05) suggests that the association is statistically significant, indicating that we can reject the null hypothesis and conclude that there is an association between the variables.
#
# Now, let's interpret the results for each variable:
#
# - **'fuel_code'**: The Chi-Square value is 330.05, and the P-value is very close to zero (2.25e-63), indicating a highly significant association between the type of fuel and other variables in the dataset.
#
# - **'seller_type_code'**: The Chi-Square value is 26.25, and the P-value is very small (0.0002), indicating a significant association between the seller type and other variables.
#
# - **'transmission_code'**: The Chi-Square value is 122.62, and the P-value is very close to zero (2.11e-26), indicating a highly significant association between the transmission type and other variables.
#
# - **'owner_code'**: The Chi-Square value is 291.54, and the P-value is very close to zero (2.80e-55), indicating a highly significant association between the ownership history and other variables.
#
# - **'cluster'**: The Chi-Square value is extremely high (253020), and the P-value is zero. This suggests an extremely significant association between the clusters identified through K-Means clustering and the other variables in the dataset.
#
# In summary, the Chi-Square Test of Independence results indicate strong associations between each categorical variable and other variables in the dataset, suggesting that these variables are not independent of each other. This information is valuable for understanding the relationships and dependencies within the dataset, which can inform further analysis and decision-making processes.
#
# The Chi-Square Test of Independence results provide valuable insights into the relationships between categorical variables and the clusters identified through K-Means clustering. Here's how we can interpret its significance for clustering:
#
# 1. **Significant Associations**: A significant association between the clusters and categorical variables indicates that the clustering algorithm has successfully captured underlying patterns or structures in the data. This suggests that the clusters are not random groupings but rather meaningful segments that exhibit distinct characteristics based on the categorical variables.
#
# 2. **Informative Features**: The significant associations suggest that the categorical variables (e.g., fuel type, seller type, transmission type, ownership history) contribute significantly to the clustering process. This implies that these features are informative in distinguishing between different clusters, leading to more interpretable and actionable clustering results.
#
# 3. **Interpretability**: Strong associations between clusters and categorical variables enhance the interpretability of the clustering results. Analysts can use these associations to gain insights into the characteristics and behaviors of each cluster, facilitating more targeted analysis, and decision-making.
#
# 4. **Validity of Clusters**: The significance of the associations validates the effectiveness of the clustering algorithm in partitioning the data into meaningful groups based on both categorical and numerical variables. It suggests that the identified clusters are not arbitrary but reflect genuine differences or similarities in the data.
#
# Overall, the significant associations observed through the Chi-Square Test of Independence indicate that the clustering results are meaningful and informative. They provide confidence in the validity and utility of the clusters for further analysis and decision-making processes. Therefore, this outcome is favorable for clustering, as it suggests that the clusters have captured relevant patterns and structures in the data.

# %%
from scipy.stats import f_oneway

# List of features for ANOVA
features = ['selling_price', 'km_driven', 'selling_price_mmnorm', 'km_driven_mmnorm']

# Initialize an empty dictionary to store ANOVA results
anova_results = {}

# Iterate over unique cluster labels
for cluster_label in train_new_df['cluster'].unique():
    # Filter dataframe for the current cluster
    cluster_df = train_new_df[train_new_df['cluster'] == cluster_label]

    # Initialize an empty dictionary to store ANOVA results for the current cluster
    cluster_anova_results = {}

    # Perform ANOVA for each feature
    for feature in features:
        # Perform ANOVA test
        anova_result = f_oneway(*[train_new_df[train_new_df['cluster'] == i][feature] for i in train_new_df['cluster'].unique()])
        # Store ANOVA result
        cluster_anova_results[feature] = anova_result

    # Store ANOVA results for the current cluster
    anova_results[cluster_label] = cluster_anova_results

# Print ANOVA results
for cluster_label, cluster_anova_result in anova_results.items():
    print(f"Cluster {cluster_label} ANOVA Results:")
    for feature, result in cluster_anova_result.items():
        print(f"{feature}: F-value = {result.statistic}, p-value = {result.pvalue}")
# Out:
# Cluster 3 ANOVA Results:
# selling_price: F-value = 180718.89624241655, p-value = 0.0
# km_driven: F-value = 38.63177186862955, p-value = 6.141954680787818e-25
# selling_price_mmnorm: F-value = 180718.89624241623, p-value = 0.0
# km_driven_mmnorm: F-value = 38.631771868629585, p-value = 6.141954680787818e-25
# Cluster 0 ANOVA Results:
# selling_price: F-value = 180718.89624241655, p-value = 0.0
# km_driven: F-value = 38.63177186862955, p-value = 6.141954680787818e-25
# selling_price_mmnorm: F-value = 180718.89624241623, p-value = 0.0
# km_driven_mmnorm: F-value = 38.631771868629585, p-value = 6.141954680787818e-25
# Cluster 1 ANOVA Results:
# selling_price: F-value = 180718.89624241655, p-value = 0.0
# km_driven: F-value = 38.63177186862955, p-value = 6.141954680787818e-25
# selling_price_mmnorm: F-value = 180718.89624241623, p-value = 0.0
# km_driven_mmnorm: F-value = 38.631771868629585, p-value = 6.141954680787818e-25
# Cluster 2 ANOVA Results:
# ...

# %% [markdown]
# The ANOVA results indicate whether there are statistically significant differences in the means of the features across different clusters. Here's what each part of the ANOVA results means:
#
# - **Cluster Label**: This indicates which cluster the ANOVA results correspond to.
#
# - **ANOVA Results for Each Feature**:
#   - **selling_price**: The F-value is a measure of variation between the means of selling prices in different clusters relative to the variation within each cluster. In this case, the extremely high F-value indicates significant differences in selling prices between clusters. The p-value is practically zero, suggesting that the observed differences are highly unlikely to have occurred by chance.
#   - **km_driven**: Similarly, the F-value and p-value for kilometers driven show significant differences between clusters in terms of the average kilometers driven.
#   - **selling_price_mmnorm** and **km_driven_mmnorm**: These are likely the normalized versions of selling price and kilometers driven. The ANOVA results for these normalized features also show significant differences between clusters, indicating that the clustering is effective in capturing variations even after normalization.
#
# In summary, the ANOVA results indicate that there are statistically significant differences in the means of the features across different clusters. This suggests that the clustering algorithm has successfully partitioned the data into clusters that exhibit distinct characteristics in terms of selling prices, kilometers driven, and their normalized versions.

# %%
import time
import psutil
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns

# Start time
start_time = time.time()

# Specify the number of clusters
num_clusters = 4

# Initialize KMeans object
kmeans = KMeans(n_clusters=num_clusters, random_state=42)

# Fit KMeans clustering model to the data
kmeans.fit(train_new_df[['year_code', 'fuel_code', 'seller_type_code', 'transmission_code', 'owner_code', 'selling_price', 'km_driven', 'selling_price_mmnorm', 'km_driven_mmnorm']])

# End time
end_time = time.time()

# Total time taken
time_taken = end_time - start_time
print("Time taken by K-Means for k=4:", "{:.4f} seconds".format(time_taken))

# Memory used by the KMeans model
memory_used = psutil.Process().memory_info().rss / 1024 / 1024  # Memory in MB
print("Memory used by K-Means for k=4:", "{:.2f} MB".format(memory_used))

# Get cluster labels
cluster_labels = kmeans.labels_

# Add cluster labels to DataFrame
train_new_df['cluster'] = cluster_labels

# Get centroids of each cluster
centroids = kmeans.cluster_centers_

# Visualize the clusters using seaborn
plt.figure(figsize=(10, 6))
sns.scatterplot(data=train_new_df, x='selling_price', y='km_driven', hue='cluster', palette='viridis', s=100)
plt.scatter(centroids[:, 5], centroids[:, 6], marker='*', s=300, c='black', label='Centroids')
plt.xlabel('Selling Price')
plt.ylabel('Kilometers Driven')
plt.title('K-means Clustering with Centroids')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()

# Plot paired plots for each variable
sns.pairplot(train_new_df, hue='cluster', palette='viridis')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Time taken by K-Means for k=4: 2.9133 seconds
# Memory used by K-Means for k=4: 331.25 MB
# <ipython-input-14-0574b325e990>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_new_df['cluster'] = cluster_labels

# %% [markdown]
# ***Paired Plots in Clustering Analysis***
#
# ### Introduction
#
# In clustering analysis, understanding the relationships between variables and how they relate to the formation of clusters is crucial for interpreting the results of the clustering algorithm. Paired plots, also known as scatterplot matrices, are powerful visualization tools that facilitate this understanding by providing insights into the multivariate structure of the data.
#
# ### Theory of Paired Plots
#
# Paired plots consist of a grid of scatterplots where each variable is plotted against every other variable in the dataset. This results in a comprehensive visualization of the relationships between pairs of variables. Along the diagonal of the grid, histograms or density plots of individual variables are displayed to show their distributions.
#
# ### Importance in Clustering
#
# 1. **Visualizing Cluster Separation**: Paired plots allow us to visualize how well clusters are separated in multivariate space. By examining the scatterplots, we can assess the degree of separation between clusters and identify any overlapping regions, which helps in evaluating the quality of the clustering algorithm.
#
# 2. **Identifying Cluster Patterns**: Paired plots help in identifying patterns within clusters. By observing the relationships between pairs of variables within the same cluster, we can gain insights into the characteristics of the clusters and understand the underlying structure of the data.
#
# 3. **Detecting Outliers**: Paired plots aid in detecting outliers within clusters. Outliers are data points that deviate significantly from the rest of the data and may indicate errors or anomalies. By visually inspecting the scatterplots, we can identify any data points that lie far away from the cluster centroids or exhibit unusual patterns.
#
# 4. **Assessing Cluster Homogeneity**: Paired plots assist in assessing the homogeneity of clusters. Homogeneous clusters contain data points that are similar to each other, while heterogeneous clusters contain data points that are dissimilar. By examining the scatterplots, we can determine whether clusters exhibit similar patterns across different pairs of variables, which provides insights into their homogeneity.
#
# 5. **Feature Selection**: Paired plots help in feature selection for clustering. By visualizing the relationships between pairs of variables, we can identify which variables are most relevant for distinguishing between clusters and which variables may be redundant or less informative.
#
# ### Conclusion
#
# Paired plots are valuable tools in clustering analysis, providing a comprehensive visualization of the relationships between variables and their importance in the formation and interpretation of clusters. By leveraging the insights gained from paired plots, researchers and practitioners can make informed decisions about clustering algorithms, feature selection, and cluster interpretation.
